# %% [markdown]
# # word2vector 기반 유저 프로파일 / 딜 피쳐
# * logistic regression
# * gradient boost classifier

# %%
import requests
import time
import urllib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import json
import elasticsearch
import csv
import pickle
from operator import itemgetter
import pandas as pd

# %% [markdown]
# # 예측 결과 로딩

# %% [markdown]
# # Elastic Search 를 이용

# %%
es = elasticsearch.Elasticsearch('twiceSpark1:9200')

def es_search(es, deal_ids):
    res = es.search(index='ojm5', body={'query': {'ids':{'values':deal_ids}}}, size=100)
    n = res['hits']['total']
    dic = {}
    for hit in res['hits']['hits']:
        dic[hit['_id']] =  hit['_source']
    return dic

# %%
def show_preds(pred):
    img_base_url=r'http://img.wemep.co.kr/'
    history = es_search(es, pred[0])
        
    fig, axes = plt.subplots(ncols=len(pred[0]), figsize=(16,16))
    
    for i, h in enumerate(pred[0]):
        title = history[h]['_2']
        img = history[h]['_3']
        f = urllib.request.urlopen(img_base_url+img)
        a = plt.imread(f, format='jpg')
        axes[i].imshow(a)
        axes[i].set_title("{}".format(title))
        axes[i].axis('off')
    plt.show()
    
    candidates = list(map(lambda x: x[0], pred[1]))
    res = es_search(es, candidates)
    
    i = 0
    for prod, slot, prob in pred[1]:
        i+=1
        if prod in res:
            cat = res[prod]['_4']['_5']
            title = res[prod]['_2']
            img = res[prod]['_3']
            #print('{}[{}].{}.prod {}.slot {}.prob {}'.format(title, cat, img, prod, slot, prob))
            #continue
            
            f = urllib.request.urlopen(img_base_url+img)        
            # read the image file in a numpy array
            a = plt.imread(f, format='jpg')
            plt.imshow(a)
            plt.title("{}[{}] score:{} {} [{}]".format(i, slot, prob, title, cat))
            plt.axis('off')
            plt.show()

        else:
            print('no entry for product {}.slot {}.prob {}'.format(prod, slot, prob))

# %%
def show_history_only(pred):
    img_base_url=r'http://img.wemep.co.kr/'
    history = es_search(es, pred[0])
        
    fig, axes = plt.subplots(ncols=len(pred[0]), figsize=(16,16))
    
    for i, h in enumerate(pred[0]):
        title = history[h]['_2']
        img = history[h]['_3']
        f = urllib.request.urlopen(img_base_url+img)
        a = plt.imread(f, format='jpg')
        axes[i].imshow(a)
        axes[i].set_title("{}".format(title))
        axes[i].axis('off')
    plt.show()

# %%
def show_item_b(item_b, show_figure=False):
    img_base_url=r'http://img.wemep.co.kr/'
    
    candidates = list(map(lambda x: x[0], item_b))
    res = es_search(es, candidates)
    
    i = 0
    for deal, slot, score in item_b:
        i+=1
        if deal in res:
            cat = res[deal]['_4']['_5']
            title = res[deal]['_2']
            img = res[deal]['_3']
            
            f = urllib.request.urlopen(img_base_url+img)        
            # read the image file in a numpy array
            a = plt.imread(f, format='jpg')
            plt.imshow(a)
            plt.title("{}[{}] score:{} {} [{}]".format(i, slot, score, title, cat))
            plt.axis('off')
            plt.show()

        else:
            print('no entry for product {} score{}'.format(deal, score))

# %%
def es_scan_extra_by_dids(dids):
    """
    dids로부터, mn, tn1를 가져온다.
    """
    res = es.search(index='dealinfos', 
                body={
                    'from':0, 'size': len(dids),
                    "_source": ["mn", "tn1", "did"],
                    'query': {
                        'ids': {'values': dids }
                        }                        
                    }
               )
    dic = {}
    for hit in res['hits']['hits']:
        dic[hit['_source']['did']] = (hit['_source']['mn'], hit['_source']['tn1'])
    return dic

# %%
def es_read_wepick_setting(dt, start_slot=20):
    """
    위픽 세팅 로딩
    """
    res = es.search(index='wepick_setting_ext', 
                body={
                    'query': {
                        'term': {'dt': dt }
                        }                        
                    }
               )
    if res['hits']['total'] > 0:
        dic = {}
        vec = []
        for s in res['hits']['hits'][0]['_source']['settings']:
            dic[s['slot']] = s['did']
            vec.append(s['did'])
        return vec, dic
    return None, None

# %%
def get_w2v_words_from_did(dids):
    """
    해당 딜번호의 워드 모음
    """
    res = es.search(index='deal_word2vec', 
                body={
                  "query": { "terms": {"v":dids } },
                  "_source": ["words", "v"],
                    "size": len(dids)
                    }
               )
    dic = {}
    if res['hits']['total'] > 0:
        for hits in res['hits']['hits']:
            dic[hits['_source']['v']] = hits['_source']['words']
    return dic

# %%
def print_user_wepick_history(user_id, day_limit, gte_slot=20, lte_slot=100):
    """
    사용자의 위픽 히스토리를 출력
    day_limit 미만
    클릭한 슬롯이: gte_slot ~ lte_slot 이어야 한다.
    """
    res = es.search(index='wepick_seq', 
                body={
                  "query": {
                    "bool": {
                      "must": { 
                        "term": {"u":user_id}
                      },
                      "filter": [
                          {
                            "range" : {
                              "rgtime" : {
                              "lt" : day_limit
                              }
                            }                              
                          },
                          {
                            "range" : {
                              "slot" : {
                              "gte" : gte_slot,
                              "lte" : lte_slot
                              }
                            }                              
                          }
                      ]
                    }
                  },
                  "size": 128,
                  "sort": {"rgtime":"desc"}
                                }
               )
    filtered = []
    if res['hits']['total'] > 0:
        filtered = []
        for hit in res['hits']['hits']:
            filtered.append((hit['_source']['v'], hit['_source']['rgtime'], hit['_source']['slot']))
    if len(filtered) > 0:
        ret = []
        deal_dic = es_scan_extra_by_dids(list(map(lambda x: x[0], filtered)))
        deal_dcs = get_w2v_words_from_did(list(map(lambda x: x[0], filtered)))
        for did, ts, slot in filtered:
            if did in deal_dic:
                if did in deal_dcs:
                    dcs = deal_dcs[did]
                else:
                    dcs = []
                ret.append((did, ts, slot, deal_dic[did][0], deal_dic[did][1], dcs))
                #print("{},{},{},{},{}".format(did, ts, slot, deal_dic[did][0], deal_dic[did][1]))
        filtered = ret
    return filtered

# %%
# 2018-04-11 21 시의 위픽 세팅 로딩
wepick_setting, wepick_dic = es_read_wepick_setting('2018-04-10 21')

# %%
deal_to_slot = dict(zip(wepick_dic.values(), wepick_dic.keys()))

# %%
deal_to_slot
# Out:
# {1432589: 13,
#  1432649: 23,
#  2271029: 34,
#  2828078: 77,
#  2833857: 44,
#  3119252: 50,
#  3182979: 30,
#  3198909: 21,
#  3312415: 61,
#  3345369: 64,
#  3360824: 19,
#  3419534: 10,
#  3433098: 39,
#  3471308: 35,
#  3477356: 27,
#  3478607: 56,
#  3479353: 16,
#  3480437: 31,
#  3495780: 68,
#  3495953: 20,
#  3499106: 65,
#  3501098: 73,
#  3501642: 87,
#  3503208: 55,
#  3503234: 7,
#  3504379: 90,
#  3504778: 43,
#  3504800: 84,
#  3505210: 6,
#  3505675: 58,
#  3506024: 80,
#  3507148: 38,
#  3508976: 42,
#  3509649: 17,
#  3511692: 14,
#  3512551: 28,
#  3512963: 60,
#  3513118: 53,
#  3513125: 1,
#  3513276: 36,
#  3513863: 46,
#  3513973: 79,
#  3514159: 47,
#  3514241: 24,
#  3514324: 9,
#  3514358: 51,
#  3514385: 91,
#  3514623: 26,
#  3514977: 63,
#  3515652: 4,
#  3516021: 49,
#  3516557: 29,
#  3516905: 18,
#  3517960: 40,
#  3518367: 85,
#  3518662: 66,
#  3518904: 12,
#  3519150: 5,
#  3519493: 11,
#  3520774: 88,
#  3520942: 103,
#  3520946: 37,
#  3520992: 78,
#  3521079: 75,
#  3521090: 57,
#  3521092: 48,
#  3521100: 33,
#  3521251: 89,
#  3521260: 76,
#  3521284: 67,
#  3521412: 54,
#  3521485: 81,
#  3521638: 70,
#  3521699: 2,
#  3521935: 86,
#  3522378: 15,
#  3522616: 92,
#  3522873: 59,
#  3522990: 45,
#  3523376: 74,
#  3523891: 69,
#  3524297: 32,
#  3524613: 25,
#  3524699: 3,
#  3525812: 22,
#  3532677: 82,
#  3541064: 41,
#  3541339: 71}

# %% [markdown]
# ## Ranking 관련

# %%
def print_result(predictions, extra):
    for _did, score in predictions:
        did = int(_did)
        if did in extra:
            if did in deal_to_slot:
                print((score, did, extra[did][0], deal_to_slot[did], extra[did][1]))
            else:
                print((score, did, extra[did][0], -1, extra[did][1]))

# %%
def print_predicted_ranks(prediction):
    print_result(prediction, es_scan_extra_by_dids(list(map(lambda x: int(x[0]), prediction))))

# %% [markdown]
# ## logistic regression 예측

# %%
lr_predict_df = pd.read_csv(r'd:\WMIND\temp\lr_review_0411_21.csv', index_col = 0)

# %%
lr_pred_dic = {}    
for id, row in lr_predict_df.iterrows():
    lr_pred_dic[id] = sorted(row.to_dict().items(), key=itemgetter(1), reverse=True)

# %%
result = print_user_wepick_history(8808210, '2018-04-11', gte_slot=20)

# %%
for did, ts, slot, title, tn, dcs in result:
    print(did, ts, slot, title, tn)
# Out:
# 3512009 2018-04-09T12:52:13.956000 22 [원더쿠폰] 첼로걸, 20%할인 쿠폰 블라우스
# 3518099 2018-04-09T12:52:06.156000 20 [리빙위크] 리베 북유럽풍5단 서랍장 리빙박스/수납함
# 3505580 2018-04-07T23:30:17.141000 86 [무료배송] 파파라치 예쁜속옷! 여성 브라팬티 세트
# 3506322 2018-04-07T23:28:10.359000 61 [원더쿠폰] 구두/신발/+20%쿠폰 여성단화
# 3513258 2018-04-07T23:26:14.835000 51 [무료배송] 원피스/블라우스/쟈켓 원피스
# 3513720 2018-04-07T23:25:45.817000 50 [하객패션] 러브캣비쥬ACC + 20%쿠폰 귀걸이
# 3503845 2018-04-07T23:25:11.899000 36 [무료배송] 백화점 리에통+20%쿠폰 여성가방
# 3498161 2018-04-06T14:16:08.994000 82 [주말직구] 명품뷰티 기초 색조200종 색조메이크업
# 3501094 2018-04-06T14:15:36.561000 72 [무료배송] 탐스백 신상 여성가방 여성가방
# 3507104 2018-04-06T14:14:06.273000 33 [무료배송] 아디다스 400종 OPEN! 런닝화/운동화 기타
# 3418313 2018-03-14T11:23:45.231000 46 [게릴라특가] 비비안/BYC 벌크스타킹 스타킹/양말
# 3402861 2018-03-14T10:25:25.376000 76 [봄신상패션] 홈쇼핑브랜드 창고개방 여성부츠
# 3413328 2018-03-14T10:24:06.173000 71 [명예의전당] 여주인공 귀걸이 206종 귀걸이
# 3410998 2018-03-14T10:22:56.670000 45 [무료배송] 브랜드 특급세일 228종 런닝화/운동화 기타
# 3395172 2018-03-14T10:22:18.852000 33 [무료배송] 이니스프리 인기품목 1+1 스킨/로션
# 3404494 2018-03-13T13:53:40.249000 75 [무료배송] 트렌치코트/원피스/봄 자켓/코트
# 3395421 2018-03-13T13:53:12.214000 38 [봄신상패션] 후아유 봄맞이 의류 티셔츠
# 3395421 2018-03-13T13:53:07.657000 38 [봄신상패션] 후아유 봄맞이 의류 티셔츠
# 3394705 2018-03-12T13:51:37.426000 88 [해피화이트] 신상 여성가방/숄더백 여성가방
# 3399907 2018-03-12T13:50:51.545000 77 [해피화이트] 봄 남여패션양말 덧신  스타킹/양말
# 3389810 2018-03-12T13:30:03.436000 42 [해피화이트] 쉬즈미스 달콤데이트룩 자켓/코트

# %%
print_predicted_ranks(lr_pred_dic[8808210])
# Out:
# (0.7936674476928148, 3527477, '[투데이특가] 니트/가디건/원피스 외', -1, '원피스')
# (0.7785943898652803, 3514459, '[심야특가] 파파야 여성 의류 모음전', -1, '티셔츠')
# (0.7219723510724965, 3521090, '[어린이날] 인기 브랜드슈즈 파격가!', 57, '유아동신발')
# (0.6890653295486322, 3501098, '[무료배송] 신디키즈 봄 아동복', 73, '아동공용의류')
# (0.6852484731095589, 3505800, '[하객패션] 스파오 봄여름 의류/잡화', -1, '티셔츠')
# (0.6785739211042247, 3508946, '[리빙위크] 쉬즈홈 Best 이불 커튼', -1, '요')
# (0.6766076320794777, 3515524, '[무료배송] 롱티/티셔츠/원피스', -1, '티셔츠')
# (0.6737932497312635, 3513863, '[하객패션] 청바지/데님/스키니진', 46, '청바지/진')
# (0.6729759298437094, 3525812, '[리빙위크] 마켓비 조명 서랍장 선반', 22, '서랍장')
# (0.6714543282374738, 3524294, '[투데이특가] 여심저격 클루나드시계', -1, '패션시계')
# (0.6684625493713289, 3521412, '[투데이특가] 원피스/반팔티/맨투맨', 54, '티셔츠')
# (0.6653919932217346, 3508976, '[하객패션] 마이수야, 20% 할인쿠폰', 42, '블라우스')
# (0.6621619841484573, 3513973, '[투데이특가] 원피스/블라우스/스커', 79, '원피스')
# (0.6591598507445531, 3513787, '[리빙위크] 3M 정전기청소포/물걸레', -1, '밀대/청소포')
# (0.6507917476506134, 3525317, '[무료배송] 빅사이즈/원피스/롱티', -1, '원피스')
# (0.6487084366814696, 3544419, '[게릴라특가] 봄맞이 카페트 150x200', -1, '카페트/러그')
# (0.6395921595962396, 3525500, '[하객패션] 포커스 봄구성완벽해', -1, '티셔츠')
# (0.6379578135348503, 3515690, '[투데이특가] 닥스셔츠 긴/반팔 BEST', -1, '셔츠/남방')
# (0.6291220603121597, 3507148, '[위클리브랜드] 바쏘옴므 +20%쿠폰', 38, '셔츠/남방')
# (0.6155574590311922, 3516938, '[원더쿠폰] 심쿵! 남/녀 선착순특가!', -1, '티셔츠')
# (0.6078424946052138, 3346365, '[결혼해봄] 위닉스 제습기 5종', -1, '제습기')
# (0.602041843710961, 3504137, '[리빙위크] 비즈니스보루네오 소파', -1, '소파')
# (0.6006457837532824, 3527053, '[투데이특가] 더사랑이 여름 아동복', -1, '아동공용의류')
# (0.5951147540178241, 3522395, '[롯데] 르까프 아동/성인 빅세일', -1, '남성 티셔츠/상의 기타')
# (0.589846201719842, 3512593, '[무료배송] 봄 아동복 브랜드 연합전', -1, '아동공용의류')
# (0.5872673066234849, 3527575, '[무료배송] 프롬유 ~20%할인쿠폰', -1, '티셔츠')
# (0.58559051066364, 3515458, '[어린이날] 크록스키즈 단독 20%쿠폰', -1, '아동공용의류')
# (0.5777110038418445, 3495953, '[무료배송] 아이도 어른도 크록스!', 20, '스포츠 샌들')
# (0.5719678321997694, 3529165, '[하객패션] 락피쉬 18년S/S+20%쿠폰!', -1, '여성단화')
# (0.5649265768448142, 3518099, '[리빙위크] 리베 북유럽풍5단 서랍장', -1, '리빙박스/수납함')
# (0.5643557184289961, 3526985, '[원더쿠폰] 봄 귀걸이,추가할인쿠폰', -1, '귀걸이')
# (0.563470070013272, 3520946, '[리빙위크] 글라스락 밀폐용기 142종', 37, '밀폐용기')
# (0.5632187063043498, 3521050, '[하객패션] 엔비룩 봄신상최애템~', -1, '블라우스')
# (0.5551068863699675, 3521785, '[쿠폰할인] 중고폰 노트5/S7/엣지', -1, '공기계-미사용/미개봉')
# (0.5537977720030982, 3522402, '[무료배송] 에비수 본사특가 20%쿠폰', -1, '티셔츠')
# (0.5528700433072968, 3527569, '[투데이특가] 아디다스 그래픽스케일', -1, '반팔 티셔츠')
# (0.5450579768914011, 3524297, '[심야특가] 신발/운동화/구두/슬립온', 32, '가보시/웨지힐/통굽')
# (0.5426542729766193, 3503208, '[리빙위크] 블룸엣홈 식기&주방용품', 55, '조리도구')
# (0.538398739515087, 3521284, '[어린이날] 월튼 나들이 룩 ', 67, '아동공용의류')
# (0.5343119752931534, 3509105, '[무료배송] 미니로이 예쁨한도초과!', -1, '여아의류')
# (0.5102933357821667, 3471308, '[타오케노이] 김스낵 14종 1+1', 35, '과자/안주')
# (0.508951361732484, 3528363, '[하객패션] 백화점 잡화 267종! +20%', -1, '벨트')
# (0.504565532853743, 1438471, '[20%쿠폰] 니베아 립밤 바디로션 ', -1, '립케어')
# (0.5032450553545418, 3009333, '[투데이특가] 립매트 립스틱 블러셔', -1, '색조메이크업')
# (0.5025384675939781, 3512215, '[6천원쿠폰] 기습쿠폰전 오늘마지막!', -1, '색조메이크업')
# (0.4962857434055206, 3544562, '[게릴라특가] 실리콘 주방용품 모음', -1, '조리도구')
# (0.4961076369610744, 3533188, '[투데이특가] 쁘띠첼 과일젤리 15개', -1, '캔디/껌/젤리')
# (0.4908224287519266, 3515873, '[투데이특가] 레이스 덧신 1+1+1', -1, '스타킹/양말')
# (0.4857234262367195, 3513766, '[어린이날] 해피버스 7부/자가드내의', -1, '내의/잠옷/속옷')
# (0.4781894691258993, 3514331, '[주간특가] 캐릭터 아동 실내복 모음', -1, '내의/잠옷/속옷')
# (0.476869894090809, 3119538, 'LG 디오스 매직스페이스 S839W30', -1, '양문형 냉장고')
# (0.4753006880019055, 3527824, '[투데이특가] 우리밀 아이국수 8인분', -1, '아기간식/아기음료')
# (0.4619673208509103, 3528869, '[무료배송] 콜핑/BTR 파격세일 252종', -1, '등산의류 기타')
# (0.4562414675922906, 3514241, '[엄마니까] 봄땡처리선착순+20%쿠폰', 24, '아동공용의류')
# (0.4488147850686376, 3503294, '[타임특가] 허니로스티드 피넛 4ea', -1, '캔디/껌/젤리')
# (0.4479915611243422, 3517002, '[주간특가] 단독! 봄 한정특가 90%!', -1, '블라우스')
# (0.4445603240294577, 3532552, '[투데이특가] 맑음 배도라지 50팩', -1, '아기간식/아기음료')
# (0.4439701841753105, 3515414, '[투데이특가] 오뚜기 컵누들 10+5개', -1, '즉석밥/국/카레')
# (0.44315422825932943, 3480437, '[투데이특가] 동서 1000 5단 서랍장', 31, '서랍장')
# (0.4381793144083091, 3525346, '[삼성생명 다이렉트] 보험 이벤트', -1, '기타')
# (0.4380855161439934, 3521451, '[투데이특가] 뮤지컬 닥터지바고 ', -1, '라이선스')
# (0.4366024027658147, 3512551, '[투데이특가] 언더아머 티셔츠 리퍼', 28, '반팔 티셔츠')
# (0.43471822590631226, 3068897, '[가전쿠폰] LG 13kg 통돌이세탁기', -1, '일반 세탁기')
# (0.4322735029242895, 3527631, '[투데이특가] 자외선차단 암막우산', -1, '생활잡화')
# (0.4315328069447747, 3524983, '[쿠폰할인] 코지마 안마의자 ', -1, '안마의자')
# (0.4255318010414353, 3505573, '[무료배송] 까만색 잇몸치약 130g ', -1, '칫솔/치약')
# (0.42307001946309547, 3525068, '[엄마니까] 쁘띠뮤 여름 횡재가격!', -1, '아동공용의류')
# (0.4157922859472719, 3527675, '[투데이특가] 파크론 주방매트 대+소', -1, '카페트/러그')
# (0.4153431210206669, 3491838, '[리빙위크] 위즈홈 옷정리트레이 54P', -1, '선반/진열대')
# (0.41402887039111175, 3515997, '[블랙데이] 짜장면 치즈 케이크 大', -1, '초콜릿')
# (0.41137142487459577, 3538943, '[투데이특가] 통등심돈까스100g 10장', -1, '가공육/양념육류')
# (0.4107176183758479, 3529131, '휴비딕 체온계 & 탕온도 특가전', -1, '유아건강/유아위생용품')
# (0.4036998488573403, 3312415, '[무료배송] 꿈토리 물티슈 10+10+2', 61, '물티슈 기타')
# (0.3932977472345922, 3539755, '[게릴라특가] 판퍼즐&코코몽자석놀이', -1, '유아퍼즐')
# (0.3918758057058822, 3521260, '[투데이특가] 광천 전장김 1봉 특가!', 76, '김')
# (0.3918633886588296, 3517009, '[투데이특가] 금구운란 30구 1판', -1, '과자/안주')
# (0.3874827419947831, 3516021, '[투데이특가] 갈바닉 워터필링기 NEW', 49, '피부관리기기')
# (0.3811273710127886, 3527861, '[투데이특가] 장조림 2팩+ 본죽 2팩!', -1, '반찬')
# (0.3802150617158525, 3119252, '[역시트롬] LG 드럼세탁기 모음', 50, '드럼세탁기')
# (0.3779116672431314, 3532677, '[게릴라특가] 궁중 너비아니 4팩', 82, '가공육/양념육류')
# (0.3766736524913978, 3492158, '[할인사건] 홍콩VS마카오 항공&자유', -1, '홍콩')
# (0.3713495950885763, 3061867, '[추가쿠폰] 삼성 냉장고 RH81K8050SA', -1, '양문형 냉장고')
# (0.36777669653065936, 3513822, '[투데이특가] 완숙 토마토 (중대)3kg', -1, '과일')
# (0.362376827960326, 3514159, '[리빙위크] 퀸센스 빠야팬 24cm 외 ', 47, '냄비')
# (0.3613849517288592, 3521935, '[투데이특가] 호떡쌀군만두1.2kg 1+1', 86, '만두/피자/떡볶이')
# (0.3551600731407145, 3483431, '[무료배송] 입맛살리는 명란파치 1kg', -1, '젓갈')
# (0.35166537796880976, 3511172, '[컬러풀] GTX1060 6GB 그래픽카드', -1, '그래픽카드')
# (0.3428376387929811, 3518630, '[투데이특가] 꺾어먹는 비요뜨 12개', -1, '두유/우유')
# (0.34147739584070425, 3524547, '[투데이특가] 1+ 한우 제비추리150g', -1, '한우')
# (0.3412156042500881, 3522873, '[투데이특가] 요미요미 떡뻥 8팩', 59, '아기간식/아기음료')
# (0.33426341507316565, 3521723, '[투데이특가] 샤오미 공기청정기', -1, '공기청정기')
# (0.3224970007595538, 3486081, '사이판 월드 골드 4/5일+마나가하', -1, '사이판')
# (0.3199468169442469, 3519199, '[투데이특가] 서울 다이노코어-VIP석', -1, '어린이뮤지컬')
# (0.31907603021898023, 3519047, '[투데이특가] 풀무원 간편국15+5입', -1, '즉석밥/국/카레')
# (0.30896528763882103, 3506713, '[플레이특가] 아티제 모바일상품권', -1, '생활쿠폰')
# (0.30621132413719043, 3530825, '[투데이특가] 무지/골지양말 7족1SET', -1, '스타킹/양말')
# (0.2845853754550101, 3512421, '[투데이특가] 휴대용 핸디 선풍기!', -1, '휴대용 선풍기')
# (0.2839215340084932, 3541064, '[위메프] 10만 포인트+5,000P', 41, '온라인 이용권')
# (0.2837329231999904, 3505675, '[투데이특가] 스테이크 도시락 출시!', 58, '다이어트보조식')
# (0.2829956631229645, 3527236, '[투데이특가] 노파머스 대용량 샴푸', -1, '샴푸/린스')
# (0.2819198901969921, 3521741, '아임닭 닭가슴살 슬라이스 15+1', -1, '닭고기')
# (0.27787274146125485, 3515704, '[투데이특가] 고급하이드로 더치커피', -1, '커피/코코아음료')
# (0.26995643929211993, 3527240, '[게릴라특가] KF94/80 황사마스크', -1, '건강관리')
# (0.26982623600550626, 3477356, '[공식판매점] LG 14kg 건조기 2종', 27, '의류 건조기/관리기')
# (0.263983374065763, 3525124, '[투데이특가] 더수 몰랑 물티슈 10팩', -1, '물티슈 기타')
# (0.2623162251491235, 3519307, '[명예의전당] 아산 스파비스 종일권', -1, '워터파크/스파')
# (0.2619705566852871, 3509649, '[리빙위크] 리빙숲 리빙박스72L 4개', 17, '리빙박스/수납함')
# (0.2593717646638241, 2258611, '[사은품증정] 리빙웰 에어프라이어', -1, '튀김기')
# (0.25301178927111473, 3433098, '[쿠폰할인] 카카오 셀카봉 삼각대', 39, '기타 휴대폰 액세서리')
# (0.2488817732341641, 3513118, '[투데이특가] 여수 와우펜션, 오션뷰', 53, '국내성인')
# (0.2425175517284463, 3512948, '[투데이특가] 눈건강 루테인 5박스', -1, '개별인정형건강식품')
# (0.22870240294210514, 3498872, '[투데이특가] 비닐/쓰레기봉투 600장', -1, '일회용품')
# (0.22738024093423265, 3507588, '[투데이특가] 보노바스켓 정리함 80L', -1, '리빙박스/수납함')
# (0.2058848977305109, 3501691, '[타임특가] 엘르걸 미니 드라이기', -1, '드라이기')
# (0.192468716336132, 3500355, '[투데이특가] 좋은느낌 생리대 38+38', -1, '화이트')
# (0.19207702595709575, 3345369, '[전국] LG 멀티형에어컨 FQ17V8WWC2 ', 64, '스탠드형 에어컨')
# (0.18306988594456872, 3516354, '[투데이특가] 닥터마밍 물티슈 캡×10', -1, '물티슈 기타')
# (0.17793306497746034, 3538332, '[리빙위크] 사이오스 샴푸 + 증정품', -1, '샴푸/린스')
# (0.1078554111371487, 3464309, '[쿠폰할인] LG 공기청정기 AS181DAW', -1, '공기청정기')
# (0.05165304203294284, 2409745, '[원더쿠폰] 과탄산소다 베이킹소다', -1, '세탁세제')

# %% [markdown]
# ## gboost 예측

# %%
gbc_predict_df = pd.read_csv(r'd:\WMIND\temp\gbc_review_0411_21.csv', index_col = 0)

# %%
gbc_pred_dic = {}    
for id, row in gbc_predict_df.iterrows():
    gbc_pred_dic[id] = sorted(row.to_dict().items(), key=itemgetter(1), reverse=True)

# %%
result = print_user_wepick_history(8808210, '2018-04-11', gte_slot=20)

# %%
for did, ts, slot, title, tn, dcs in result:
    print(did, ts, slot, title, tn)
# Out:
# 3512009 2018-04-09T12:52:13.956000 22 [원더쿠폰] 첼로걸, 20%할인 쿠폰 블라우스
# 3518099 2018-04-09T12:52:06.156000 20 [리빙위크] 리베 북유럽풍5단 서랍장 리빙박스/수납함
# 3505580 2018-04-07T23:30:17.141000 86 [무료배송] 파파라치 예쁜속옷! 여성 브라팬티 세트
# 3506322 2018-04-07T23:28:10.359000 61 [원더쿠폰] 구두/신발/+20%쿠폰 여성단화
# 3513258 2018-04-07T23:26:14.835000 51 [무료배송] 원피스/블라우스/쟈켓 원피스
# 3513720 2018-04-07T23:25:45.817000 50 [하객패션] 러브캣비쥬ACC + 20%쿠폰 귀걸이
# 3503845 2018-04-07T23:25:11.899000 36 [무료배송] 백화점 리에통+20%쿠폰 여성가방
# 3498161 2018-04-06T14:16:08.994000 82 [주말직구] 명품뷰티 기초 색조200종 색조메이크업
# 3501094 2018-04-06T14:15:36.561000 72 [무료배송] 탐스백 신상 여성가방 여성가방
# 3507104 2018-04-06T14:14:06.273000 33 [무료배송] 아디다스 400종 OPEN! 런닝화/운동화 기타
# 3499864 2018-04-05T08:49:49.479000 68 [무료배송] 매장판 리복 180종 런닝화
# 3483501 2018-04-05T08:48:40.225000 49 [봄신상패션] 스파오 티셔츠/팬츠 外 티셔츠
# 3472770 2018-04-05T08:47:11.305000 40 [봄신상패션] 엔비룩 추가 할인쿠폰! 블라우스
# 3505054 2018-04-05T08:47:01.390000 32 [타임특가] 펀업 블럭 핸드폰 케이스 스마트 액세서리
# 3395172 2018-03-14T10:22:18.852000 33 [무료배송] 이니스프리 인기품목 1+1 스킨/로션
# 3404494 2018-03-13T13:53:40.249000 75 [무료배송] 트렌치코트/원피스/봄 자켓/코트
# 3395421 2018-03-13T13:53:12.214000 38 [봄신상패션] 후아유 봄맞이 의류 티셔츠
# 3395421 2018-03-13T13:53:07.657000 38 [봄신상패션] 후아유 봄맞이 의류 티셔츠
# 3394705 2018-03-12T13:51:37.426000 88 [해피화이트] 신상 여성가방/숄더백 여성가방
# 3399907 2018-03-12T13:50:51.545000 77 [해피화이트] 봄 남여패션양말 덧신  스타킹/양말
# 3389810 2018-03-12T13:30:03.436000 42 [해피화이트] 쉬즈미스 달콤데이트룩 자켓/코트

# %%
print_predicted_ranks(gbc_pred_dic[8808210])
# Out:
# (0.806966813568699, 3525812, '[리빙위크] 마켓비 조명 서랍장 선반', '서랍장')
# (0.7381653562475311, 3505800, '[하객패션] 스파오 봄여름 의류/잡화', '티셔츠')
# (0.7250965637694399, 3508976, '[하객패션] 마이수야, 20% 할인쿠폰', '블라우스')
# (0.7238992581340316, 3513863, '[하객패션] 청바지/데님/스키니진', '청바지/진')
# (0.7113136103323243, 3522395, '[롯데] 르까프 아동/성인 빅세일', '남성 티셔츠/상의 기타')
# (0.7041484917624345, 3514459, '[심야특가] 파파야 여성 의류 모음전', '티셔츠')
# (0.7024690784010017, 3525500, '[하객패션] 포커스 봄구성완벽해', '티셔츠')
# (0.7002006587651551, 3527477, '[투데이특가] 니트/가디건/원피스 외', '원피스')
# (0.6940005388097746, 3515690, '[투데이특가] 닥스셔츠 긴/반팔 BEST', '셔츠/남방')
# (0.6933413845440604, 3346365, '[결혼해봄] 위닉스 제습기 5종', '제습기')
# (0.6932612798325845, 3529165, '[하객패션] 락피쉬 18년S/S+20%쿠폰!', '여성단화')
# (0.6757429646077227, 3524297, '[심야특가] 신발/운동화/구두/슬립온', '가보시/웨지힐/통굽')
# (0.6756433847120844, 3521284, '[어린이날] 월튼 나들이 룩 ', '아동공용의류')
# (0.6631775562271357, 3521050, '[하객패션] 엔비룩 봄신상최애템~', '블라우스')
# (0.6621463133800314, 3521412, '[투데이특가] 원피스/반팔티/맨투맨', '티셔츠')
# (0.6539876609560208, 3515524, '[무료배송] 롱티/티셔츠/원피스', '티셔츠')
# (0.6521534766796955, 3527575, '[무료배송] 프롬유 ~20%할인쿠폰', '티셔츠')
# (0.6519643755847352, 3507148, '[위클리브랜드] 바쏘옴므 +20%쿠폰', '셔츠/남방')
# (0.6486066521817627, 3522402, '[무료배송] 에비수 본사특가 20%쿠폰', '티셔츠')
# (0.6389645765759558, 3495953, '[무료배송] 아이도 어른도 크록스!', '스포츠 샌들')
# (0.6376240057210195, 3521090, '[어린이날] 인기 브랜드슈즈 파격가!', '유아동신발')
# (0.637245264963305, 3513973, '[투데이특가] 원피스/블라우스/스커', '원피스')
# (0.6262001571662322, 3512593, '[무료배송] 봄 아동복 브랜드 연합전', '아동공용의류')
# (0.6181218029076742, 3516938, '[원더쿠폰] 심쿵! 남/녀 선착순특가!', '티셔츠')
# (0.6161630983696177, 3501098, '[무료배송] 신디키즈 봄 아동복', '아동공용의류')
# (0.6158906365831677, 3527569, '[투데이특가] 아디다스 그래픽스케일', '반팔 티셔츠')
# (0.5855227906042346, 3503208, '[리빙위크] 블룸엣홈 식기&주방용품', '조리도구')
# (0.5853627480372617, 3009333, '[투데이특가] 립매트 립스틱 블러셔', '색조메이크업')
# (0.5845235992012867, 3527053, '[투데이특가] 더사랑이 여름 아동복', '아동공용의류')
# (0.5748669195048659, 3509105, '[무료배송] 미니로이 예쁨한도초과!', '여아의류')
# (0.5736536968124379, 3525317, '[무료배송] 빅사이즈/원피스/롱티', '원피스')
# (0.561708724090694, 3514241, '[엄마니까] 봄땡처리선착순+20%쿠폰', '아동공용의류')
# (0.5510608264225801, 3520946, '[리빙위크] 글라스락 밀폐용기 142종', '밀폐용기')
# (0.5506777337072294, 3526985, '[원더쿠폰] 봄 귀걸이,추가할인쿠폰', '귀걸이')
# (0.5493252086099571, 3512551, '[투데이특가] 언더아머 티셔츠 리퍼', '반팔 티셔츠')
# (0.5409439058740065, 3515997, '[블랙데이] 짜장면 치즈 케이크 大', '초콜릿')
# (0.5323803392531613, 3515458, '[어린이날] 크록스키즈 단독 20%쿠폰', '아동공용의류')
# (0.5192877504688699, 3480437, '[투데이특가] 동서 1000 5단 서랍장', '서랍장')
# (0.5145741106269456, 3528363, '[하객패션] 백화점 잡화 267종! +20%', '벨트')
# (0.5078493107268855, 3544562, '[게릴라특가] 실리콘 주방용품 모음', '조리도구')
# (0.5034579061115784, 3514331, '[주간특가] 캐릭터 아동 실내복 모음', '내의/잠옷/속옷')
# (0.4980413134833002, 3503294, '[타임특가] 허니로스티드 피넛 4ea', '캔디/껌/젤리')
# (0.4911780377046245, 3518099, '[리빙위크] 리베 북유럽풍5단 서랍장', '리빙박스/수납함')
# (0.4891151246094111, 3504137, '[리빙위크] 비즈니스보루네오 소파', '소파')
# (0.477888342183414, 3532677, '[게릴라특가] 궁중 너비아니 4팩', '가공육/양념육류')
# (0.4667567225578248, 3513766, '[어린이날] 해피버스 7부/자가드내의', '내의/잠옷/속옷')
# (0.466498850323912, 3524294, '[투데이특가] 여심저격 클루나드시계', '패션시계')
# (0.4416440750597319, 3525068, '[엄마니까] 쁘띠뮤 여름 횡재가격!', '아동공용의류')
# (0.4413932775886807, 3544419, '[게릴라특가] 봄맞이 카페트 150x200', '카페트/러그')
# (0.4358020628360916, 3521935, '[투데이특가] 호떡쌀군만두1.2kg 1+1', '만두/피자/떡볶이')
# (0.43384457735811705, 3513822, '[투데이특가] 완숙 토마토 (중대)3kg', '과일')
# (0.4329968876142272, 3515873, '[투데이특가] 레이스 덧신 1+1+1', '스타킹/양말')
# (0.43159903809295785, 3517002, '[주간특가] 단독! 봄 한정특가 90%!', '블라우스')
# (0.4298782977818711, 3524983, '[쿠폰할인] 코지마 안마의자 ', '안마의자')
# (0.4294789475969042, 1438471, '[20%쿠폰] 니베아 립밤 바디로션 ', '립케어')
# (0.428051351324196, 3527631, '[투데이특가] 자외선차단 암막우산', '생활잡화')
# (0.4230931410474415, 3533188, '[투데이특가] 쁘띠첼 과일젤리 15개', '캔디/껌/젤리')
# (0.4205800505156797, 3513787, '[리빙위크] 3M 정전기청소포/물걸레', '밀대/청소포')
# (0.4185290690538489, 3514159, '[리빙위크] 퀸센스 빠야팬 24cm 외 ', '냄비')
# (0.4166059674136132, 3516021, '[투데이특가] 갈바닉 워터필링기 NEW', '피부관리기기')
# (0.4123225831122567, 3508946, '[리빙위크] 쉬즈홈 Best 이불 커튼', '요')
# (0.4053395887532874, 3521451, '[투데이특가] 뮤지컬 닥터지바고 ', '라이선스')
# (0.4040905719886796, 3515414, '[투데이특가] 오뚜기 컵누들 10+5개', '즉석밥/국/카레')
# (0.40144841975015066, 3471308, '[타오케노이] 김스낵 14종 1+1', '과자/안주')
# (0.3997983756578217, 3512215, '[6천원쿠폰] 기습쿠폰전 오늘마지막!', '색조메이크업')
# (0.39407811746402893, 3527240, '[게릴라특가] KF94/80 황사마스크', '건강관리')
# (0.3903419581952479, 3528869, '[무료배송] 콜핑/BTR 파격세일 252종', '등산의류 기타')
# (0.3859816508537148, 3527675, '[투데이특가] 파크론 주방매트 대+소', '카페트/러그')
# (0.3852647943335134, 3519047, '[투데이특가] 풀무원 간편국15+5입', '즉석밥/국/카레')
# (0.3828582117523457, 3501691, '[타임특가] 엘르걸 미니 드라이기', '드라이기')
# (0.3812051784000841, 3527824, '[투데이특가] 우리밀 아이국수 8인분', '아기간식/아기음료')
# (0.3765829887261645, 3516354, '[투데이특가] 닥터마밍 물티슈 캡×10', '물티슈 기타')
# (0.3744542987560963, 3513118, '[투데이특가] 여수 와우펜션, 오션뷰', '국내성인')
# (0.3720582293561812, 3538943, '[투데이특가] 통등심돈까스100g 10장', '가공육/양념육류')
# (0.3713818714824838, 3517009, '[투데이특가] 금구운란 30구 1판', '과자/안주')
# (0.3649592286530111, 3530825, '[투데이특가] 무지/골지양말 7족1SET', '스타킹/양말')
# (0.3632896596180159, 3524547, '[투데이특가] 1+ 한우 제비추리150g', '한우')
# (0.3601637534245096, 3527861, '[투데이특가] 장조림 2팩+ 본죽 2팩!', '반찬')
# (0.3590795162364734, 3521723, '[투데이특가] 샤오미 공기청정기', '공기청정기')
# (0.3531228457071908, 3539755, '[게릴라특가] 판퍼즐&코코몽자석놀이', '유아퍼즐')
# (0.3433466589510521, 3515704, '[투데이특가] 고급하이드로 더치커피', '커피/코코아음료')
# (0.33790538175695256, 3525346, '[삼성생명 다이렉트] 보험 이벤트', '기타')
# (0.3370192522209745, 3521741, '아임닭 닭가슴살 슬라이스 15+1', '닭고기')
# (0.32957322035916997, 3483431, '[무료배송] 입맛살리는 명란파치 1kg', '젓갈')
# (0.3292533870394769, 3119538, 'LG 디오스 매직스페이스 S839W30', '양문형 냉장고')
# (0.3245825713672114, 3433098, '[쿠폰할인] 카카오 셀카봉 삼각대', '기타 휴대폰 액세서리')
# (0.3213628733318148, 3521260, '[투데이특가] 광천 전장김 1봉 특가!', '김')
# (0.3146453508403632, 3511172, '[컬러풀] GTX1060 6GB 그래픽카드', '그래픽카드')
# (0.3133725446381132, 3061867, '[추가쿠폰] 삼성 냉장고 RH81K8050SA', '양문형 냉장고')
# (0.3079946227775171, 3529131, '휴비딕 체온계 & 탕온도 특가전', '유아건강/유아위생용품')
# (0.30179817255797964, 3527236, '[투데이특가] 노파머스 대용량 샴푸', '샴푸/린스')
# (0.2931254729235288, 3507588, '[투데이특가] 보노바스켓 정리함 80L', '리빙박스/수납함')
# (0.2924967680558969, 3119252, '[역시트롬] LG 드럼세탁기 모음', '드럼세탁기')
# (0.29219694052626033, 3491838, '[리빙위크] 위즈홈 옷정리트레이 54P', '선반/진열대')
# (0.28390040773555764, 3519199, '[투데이특가] 서울 다이노코어-VIP석', '어린이뮤지컬')
# (0.27645024369115184, 3505573, '[무료배송] 까만색 잇몸치약 130g ', '칫솔/치약')
# (0.2722623437933921, 3345369, '[전국] LG 멀티형에어컨 FQ17V8WWC2 ', '스탠드형 에어컨')
# (0.2651946967739051, 3518630, '[투데이특가] 꺾어먹는 비요뜨 12개', '두유/우유')
# (0.2645835658923488, 3532552, '[투데이특가] 맑음 배도라지 50팩', '아기간식/아기음료')
# (0.263216140359506, 3525124, '[투데이특가] 더수 몰랑 물티슈 10팩', '물티슈 기타')
# (0.2596279251443772, 3312415, '[무료배송] 꿈토리 물티슈 10+10+2', '물티슈 기타')
# (0.25833739213864404, 3506713, '[플레이특가] 아티제 모바일상품권', '생활쿠폰')
# (0.2521221983102881, 2258611, '[사은품증정] 리빙웰 에어프라이어', '튀김기')
# (0.2513566695244594, 3521785, '[쿠폰할인] 중고폰 노트5/S7/엣지', '공기계-미사용/미개봉')
# (0.2489120455419563, 3486081, '사이판 월드 골드 4/5일+마나가하', '사이판')
# (0.2429186225933669, 3512948, '[투데이특가] 눈건강 루테인 5박스', '개별인정형건강식품')
# (0.23342633717604824, 3505675, '[투데이특가] 스테이크 도시락 출시!', '다이어트보조식')
# (0.231718204732261, 3538332, '[리빙위크] 사이오스 샴푸 + 증정품', '샴푸/린스')
# (0.2280515549736978, 3068897, '[가전쿠폰] LG 13kg 통돌이세탁기', '일반 세탁기')
# (0.220897370186688, 2409745, '[원더쿠폰] 과탄산소다 베이킹소다', '세탁세제')
# (0.21297866748371813, 3512421, '[투데이특가] 휴대용 핸디 선풍기!', '휴대용 선풍기')
# (0.21258300709302053, 3509649, '[리빙위크] 리빙숲 리빙박스72L 4개', '리빙박스/수납함')
# (0.21178557368292467, 3500355, '[투데이특가] 좋은느낌 생리대 38+38', '화이트')
# (0.20267580179622027, 3522873, '[투데이특가] 요미요미 떡뻥 8팩', '아기간식/아기음료')
# (0.1980179274228672, 3477356, '[공식판매점] LG 14kg 건조기 2종', '의류 건조기/관리기')
# (0.19789413597180394, 3498872, '[투데이특가] 비닐/쓰레기봉투 600장', '일회용품')
# (0.1948728919099926, 3541064, '[위메프] 10만 포인트+5,000P', '온라인 이용권')
# (0.19327158540052625, 3519307, '[명예의전당] 아산 스파비스 종일권', '워터파크/스파')
# (0.1922740432429974, 3492158, '[할인사건] 홍콩VS마카오 항공&자유', '홍콩')
# (0.14295199029686506, 3464309, '[쿠폰할인] LG 공기청정기 AS181DAW', '공기청정기')
